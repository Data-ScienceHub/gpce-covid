# %%
import pandas as pd

# %%
# !ls
# Out:
# TFTdfCurrent.csv TFTdfTotal.csv   Untitled.ipynb   datapreptest.csv

# %%
dfo = pd.read_csv('TFTdfTotal.csv')

# %%
dfn = pd.read_csv('datapreptest.csv')

# %%
dfo
# Out:
#        Unnamed: 0  RawLabel                    Location  Time from Start  \
# 0               0       0.0       Coffee County Alabama              0.0
# 1               1       1.0       Coffee County Alabama              1.0
# 2               2       2.0       Coffee County Alabama              2.0
# 3               3       3.0       Coffee County Alabama              3.0
# 4               4       4.0       Coffee County Alabama              4.0
# ...           ...       ...                         ...              ...
# 39732       39732   39732.0  Marinette County Wisconsin            498.0
# 39733       39733   39733.0  Marinette County Wisconsin            499.0
# 39734       39734   39734.0  Marinette County Wisconsin            500.0
# 39735       39735   39735.0  Marinette County Wisconsin            501.0
# 39736       39736   39736.0  Marinette County Wisconsin            502.0
#
#        0 Cases Root 2  1 Deaths Root 2  2 Age Distribution  3 Air Pollution  \
# ...

# %%
dfn
# Out:
#        Unnamed: 0   FIPS        Date     Cases                   Name  \
# 0               0   1031  2020-02-29  0.000000        Alabama, Coffee
# 1               1   6035  2020-02-29  0.000000     California, Lassen
# 2               2   6045  2020-02-29  0.000000  California, Mendocino
# 3               3   8045  2020-02-29  0.000000     Colorado, Garfield
# 4               4  13149  2020-02-29  0.000000         Georgia, Heard
# ...           ...    ...         ...       ...                    ...
# 38547       38547  53039  2021-06-30  0.267003  Washington, Klickitat
# 38548       38548  53041  2021-06-30  0.654759      Washington, Lewis
# 38549       38549  54053  2021-06-30  0.407229   West Virginia, Mason
# 38550       38550  55069  2021-06-30  0.514045     Wisconsin, Lincoln
# 38551       38551  55075  2021-06-30  0.615485   Wisconsin, Marinette
#
#         AgeDist  AirPollution  Comorbidities  HealthDisp  Mobility  \
# ...

# %%
dfo['Location']
# Out:
# 0             Coffee County Alabama
# 1             Coffee County Alabama
# 2             Coffee County Alabama
# 3             Coffee County Alabama
# 4             Coffee County Alabama
#                     ...
# 39732    Marinette County Wisconsin
# 39733    Marinette County Wisconsin
# 39734    Marinette County Wisconsin
# 39735    Marinette County Wisconsin
# 39736    Marinette County Wisconsin
# Name: Location, Length: 39737, dtype: object

# %%
dfo[dfo['Location'] == 'Coffee County Alabama']
# Out:
#      Unnamed: 0  RawLabel               Location  Time from Start  \
# 0             0       0.0  Coffee County Alabama              0.0
# 1             1       1.0  Coffee County Alabama              1.0
# 2             2       2.0  Coffee County Alabama              2.0
# 3             3       3.0  Coffee County Alabama              3.0
# 4             4       4.0  Coffee County Alabama              4.0
# ..          ...       ...                    ...              ...
# 498         498     498.0  Coffee County Alabama            498.0
# 499         499     499.0  Coffee County Alabama            499.0
# 500         500     500.0  Coffee County Alabama            500.0
# 501         501     501.0  Coffee County Alabama            501.0
# 502         502     502.0  Coffee County Alabama            502.0
#
#      0 Cases Root 2  1 Deaths Root 2  2 Age Distribution  3 Air Pollution  \
# 0               0.0              0.0            0.482809         0.806122
# ...

# %%
dfn[dfn['Name'] == 'Alabama, Coffee']
# Out:
#        Unnamed: 0  FIPS        Date     Cases             Name   AgeDist  \
# 0               0  1031  2020-02-29  0.000000  Alabama, Coffee  0.482809
# 79             79  1031  2020-03-01  0.000000  Alabama, Coffee  0.482809
# 158           158  1031  2020-03-02  0.000000  Alabama, Coffee  0.482809
# 237           237  1031  2020-03-03  0.000000  Alabama, Coffee  0.482809
# 316           316  1031  2020-03-04  0.000000  Alabama, Coffee  0.482809
# ...           ...   ...         ...       ...              ...       ...
# 38157       38157  1031  2021-06-26  0.674314  Alabama, Coffee  0.482809
# 38236       38236  1031  2021-06-27  0.674314  Alabama, Coffee  0.482809
# 38315       38315  1031  2021-06-28  0.674314  Alabama, Coffee  0.482809
# 38394       38394  1031  2021-06-29  0.674851  Alabama, Coffee  0.482809
# 38473       38473  1031  2021-06-30  0.674851  Alabama, Coffee  0.482809
#
#        AirPollution  Comorbidities  HealthDisp  Mobility  ResidentialDense  \
# ...

# %%
dfn[dfn['Name'].isin(dfo['Location'])]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, FIPS, Date, Cases, Name, AgeDist, AirPollution, Comorbidities, HealthDisp, Mobility, ResidentialDense, DiseaseSpread, SocialDist, Testing, Transmission, VaccinationOne, VaccinationFull, TimeFromStart]
# Index: []
