# %% [markdown]
# # Setup data folder

# %%
from google.colab import drive

# %%
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd /content/gdrive/MyDrive/Research/SCITFT/
# Out:
# /content/gdrive/MyDrive/Research/SCITFT

# %%
# %ls
# Out:
# TFTCode/  TFTData/

# %% [markdown]
# # Train the fixed model

# %% [markdown]
# ## Make sure the Tensoflow version is 2.4.1
# The latest default version is 2.6.0, which is not compatible with TFT code.

# %%
# !pip install tensorflow==2.4.1
# Out:
# ...
#      |████████████████████████████████| 394.3 MB 12 kB/s
# ...
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.4.0
#     Uninstalling tensorflow-2.4.0:
#       Successfully uninstalled tensorflow-2.4.0
# ...
# '2.6.0'

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.4.1'

# %%
# %cd TFTCode/
# Out:
# /content/gdrive/MyDrive/Research/SCITFT/TFTCode

# %%
import expt_settings.configs
ExperimentConfig = expt_settings.configs.ExperimentConfig

# %%
name = "volatility"
output_folder = "../TFTData" # Please don't change this path
use_tensorflow_with_gpu = False

# %%
config = ExperimentConfig(name, output_folder)
formatter = config.make_data_formatter()

# %%
import os
from script_train_fixed_params import main as train

train(expt_name=name,
     use_gpu=use_tensorflow_with_gpu,
     model_folder=os.path.join(config.model_folder, "fixed"),
     data_csv_path=config.data_csv_path,
     data_formatter=formatter,
     use_testing_mode=True)
# Out:
# WARNING:tensorflow:From /content/gdrive/MyDrive/Research/SCITFT/TFTCode/script_train_fixed_params.py:77: The name tf.keras.backend.get_session is deprecated. Please use tf.compat.v1.keras.backend.get_session instead.
#
# *** Training from defined parameters for volatility ***
# Loading & splitting data...
# Formatting train-valid-test splits.
# Setting scalers with training data...
# *** Loading hyperparm manager ***
# *** Running calibration ***
# Params Selected:
# dropout_rate: 0.3
# hidden_layer_size: 5
# learning_rate: 0.01
# minibatch_size: 64
# max_gradient_norm: 0.01
# num_heads: 1
# stack_size: 1
# model_folder: ../TFTData/saved_models/volatility/fixed
# WARNING:tensorflow:From /content/gdrive/MyDrive/Research/SCITFT/TFTCode/script_train_fixed_params.py:121: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
# Resetting temp folder...
# *** TemporalFusionTransformer params ***
# # dropout_rate = 0.3
# ...
